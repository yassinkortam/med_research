# %%
import columator
report = """
Abra:
This is the first section.

Mega: This is the second section.
take: This is the third section.
"""
headings = ["abra", "Stake"]
print(columator.columator(report, headings))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/47/hn583msn2xv9hbr_m7tsh9880000gn/T/ipykernel_37452/1727590321.py in <module>
#       8 """
#       9 headings = ["abra", "Stake"]
# ---> 10 print(columator.columator(report, headings))
#
# ~/Documents/GitHub/med_research/ccscript/src/columator.py in columator(report, headings)
#      87
#      88         #Find the most similar heading
# ---> 89         similarities = cosine_similarity(heading_embedding, report_headings_embeddings)
#      90         closest_heading = report_headings[np.argmax(similarities)]
#      91
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/pairwise.py in cosine_similarity(X, Y, dense_output)
#    1249     # to avoid recursive import
#    1250
# -> 1251     X, Y = check_pairwise_arrays(X, Y)
#    1252
#    1253     X_normalized = normalize(X, copy=True)
#
# ...
